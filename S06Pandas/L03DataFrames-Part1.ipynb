# %%
# Name: Chaithra Kopparam Cheluvaiah
# 27 Nov 2021

# %% [markdown]
# # PANDAS DATAFRAMES - PART 1

# %%
import numpy as np
import pandas as pd
from numpy.random import randn

# %%
np.random.seed(101) # to get same random numbers

# %% [markdown]
# class pandas.DataFrame(data=None, index=None, columns=None, dtype=None, copy=None)
#
# https://pandas.pydata.org/docs/reference/api/pandas.DataFrame.html

# %%
df = pd.DataFrame(randn(5,4),['A','B','C','D','E'],['W','X','Y','Z']) # data, index args are smilar to numpy. 
# additional columns argument in pandas

df # looks like excel
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# second method of creating data frame
# keys are column names unlike panda series where keys in dict are row index

data = {'Company':['GOOGL','GOOGL','MSFT','MSFT','FB','FB'], 
        'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
        'Sales':[200,120,340,124,243,350]}

df1=pd.DataFrame(data)
df1
# Out:
#   Company   Person  Sales
# 0   GOOGL      Sam    200
# 1   GOOGL  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
# dictionary keys are column labels
df2 = pd.DataFrame({'A': ['A4', 'A5', 'A6', 'A7'],
                        'B': ['B4', 'B5', 'B6', 'B7'],
                        'C': ['C4', 'C5', 'C6', 'C7'],
                        'D': ['D4', 'D5', 'D6', 'D7']},
                         index=[0,1,2,6]) 
df2
# Out:
#     A   B   C   D
# 0  A4  B4  C4  D4
# 1  A5  B5  C5  D5
# 2  A6  B6  C6  D6
# 6  A7  B7  C7  D7

# %% [markdown]
# ### INDEXING & SELECTION

# %% [markdown]
# #### SELCTING COLUMNS: Each column is a pandas series

# %%
df['W'] # recommended way
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
type(df['W'])
# Out:
# pandas.core.series.Series

# %%
type(df)
# Out:
# pandas.core.frame.DataFrame

# %%
df.W #sql syntax to select columns (table.coumn_name) but this is not recommended

#pandas might get confused with various methods ara availale off of data frame. 
#one of the method might get overriden by column name. pandas can get confused whether you are asking for ColumnName or a method.
# Out:
# A    2.706850
# B    0.651118
# C   -2.018168
# D    0.188695
# E    0.190794
# Name: W, dtype: float64

# %%
# selecting multiple columns
df[['W','Z']] # pass list of column names

# it returns a data frame. selecting a single column will result in a series
# in jupyter notebook, it is noted by the way output is displayed.
# Out:
#           W         Z
# A  2.706850  0.503826
# B  0.651118  0.605965
# C -2.018168 -0.589001
# D  0.188695  0.955057
# E  0.190794  0.683509

# %%
# creating new column

# in pandas supports creation of new column by just specifying the column as if it already exists.

df ['new'] = df['W'] + df['Y']
df
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
# removing columns
df.drop('new') # this gives key error: "['new'] not found in axis"

# Reason being axis=0 by default. so drop method refers to index.
# Out:
# ---------------------------------------------------------------------------
# KeyError                                  Traceback (most recent call last)
# <ipython-input-13-d298873015cd> in <cell line: 2>()
#       1 # removing columns
# ----> 2 df.drop('new') # this gives key error: "['new'] not found in axis"
#       3
#       4 # Reason being axis=0 by default. so drop method refers to index.
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/frame.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    5397                 weight  1.0     0.8
#    5398         """
# -> 5399         return super().drop(
#    5400             labels=labels,
#    5401             axis=axis,
#
# /usr/local/lib/python3.9/dist-packages/pandas/util/_decorators.py in wrapper(*args, **kwargs)
#     329                     stacklevel=find_stack_level(),
#     330                 )
# --> 331             return func(*args, **kwargs)
#     332
#     333         # error: "Callable[[VarArg(Any), KwArg(Any)], Any]" has no
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in drop(self, labels, axis, index, columns, level, inplace, errors)
#    4503         for axis, labels in axes.items():
#    4504             if labels is not None:
# -> 4505                 obj = obj._drop_axis(labels, axis, level=level, errors=errors)
#    4506
#    4507         if inplace:
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/generic.py in _drop_axis(self, labels, axis, level, errors, only_slice)
#    4544                 new_axis = axis.drop(labels, level=level, errors=errors)
#    4545             else:
# -> 4546                 new_axis = axis.drop(labels, errors=errors)
#    4547             indexer = axis.get_indexer(new_axis)
#    4548
#
# /usr/local/lib/python3.9/dist-packages/pandas/core/indexes/base.py in drop(self, labels, errors)
#    6932         if mask.any():
#    6933             if errors != "ignore":
# -> 6934                 raise KeyError(f"{list(labels[mask])} not found in axis")
#    6935             indexer = indexer[~mask]
#    6936         return self.delete(indexer)
#
# KeyError: "['new'] not found in axis"

# %%
# referring to columns
df.drop('new',axis=1)
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# drop is not inplace by default to not accidentally loose information
df # 'new' column still exist
# Out:
#           W         X         Y         Z       new
# A  2.706850  0.628133  0.907969  0.503826  3.614819
# B  0.651118 -0.319318 -0.848077  0.605965 -0.196959
# C -2.018168  0.740122  0.528813 -0.589001 -1.489355
# D  0.188695 -0.758872 -0.933237  0.955057 -0.744542
# E  0.190794  1.978757  2.605967  0.683509  2.796762

# %%
df.drop('new',axis=1,inplace=True)

# %%
df # 'new' is permanently dropped
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# dropping the rows
df.drop('E') # axis=0 is default
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057

# %%
# why are the rows have axis=0 and columns have axis=1
df.shape # returns tuple

# 0 index is rows 
# 1 index is columns
# Out:
# (5, 4)

# %% [markdown]
# #### SELECTING ROWS - Each row is pandas series

# %%
df
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965
# C -2.018168  0.740122  0.528813 -0.589001
# D  0.188695 -0.758872 -0.933237  0.955057
# E  0.190794  1.978757  2.605967  0.683509

# %%
# Two ways to select rows - loc and iloc
df.loc['A'] 

# notice that we are using saquare brackets here for loc method instead of paranthesis ()

# This is little weird in pandas but that's the way it works
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.loc['A']  # it retursn series
# Out:
# W    2.706850
# X    0.628133
# Y    0.907969
# Z    0.503826
# Name: A, dtype: float64

# %%
df.iloc[2] # selects C row
# Out:
# W   -2.018168
# X    0.740122
# Y    0.528813
# Z   -0.589001
# Name: C, dtype: float64

# %%
df.loc[['A', 'B']] # # pass list of row names
# Out:
#           W         X         Y         Z
# A  2.706850  0.628133  0.907969  0.503826
# B  0.651118 -0.319318 -0.848077  0.605965

# %% [markdown]
# #### SELECTING SUBSET OF DATAFRAME

# %%
# just like numpy we can use comma notation

df.loc['B','Y'] # selects just a single value
# Out:
# -0.8480769834036315

# %%
df.loc[['A','B'],['W','Y']] # we can pass list of rows and list of columns
# Out:
#           W         Y
# A  2.706850  0.907969
# B  0.651118 -0.848077

# %% [markdown]
# #### QUICK REVIEW:
# 1. creating data frame - pd.DataFrame(data, index, columns). Ususally data is imported from a source like csv.
# 2. selecting cols - df[] pass in a column name or list of column names
# 3. each column is a series
# 4. creating new column
# 5. drop rows/columns df.drop(axis, inplace)
# 6. selecting rows - loc(label based index location) and iloc(integer based index location) methods
# 7. subsets of dataframe - df.loc[] pass the rows, columns list
