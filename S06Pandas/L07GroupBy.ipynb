# %%
# Name: Chaithra Kopparam Cheluvaiah
# Nov 28, 2021

# %% [markdown]
# # PANDAS - GROUPBY

# %%
import numpy as np
import pandas as pd

data = {'Company':['GOOGL','GOOGL','MSFT','MSFT','FB','FB'], 
        'Person':['Sam','Charlie','Amy','Vanessa','Carl','Sarah'],
        'Sales':[200,120,340,124,243,350]}

# %%
df=pd.DataFrame(data)
df
# Out:
#   Company   Person  Sales
# 0   GOOGL      Sam    200
# 1   GOOGL  Charlie    120
# 2    MSFT      Amy    340
# 3    MSFT  Vanessa    124
# 4      FB     Carl    243
# 5      FB    Sarah    350

# %%
bycomp = df.groupby('Company') # pass the column name and it returns groupby object
bycomp

# %%
# call aggregate functions on groupby object
bycomp.mean() # it will automatically ignore non-numeric columns lik 'Person'
# Out:
#          Sales
# Company
# FB       296.5
# GOOGL    160.0
# MSFT     232.0

# %%
bycomp.sum()
# Out:
#          Sales
# Company
# FB         593
# GOOGL      320
# MSFT       464

# %%
bycomp.std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOGL     56.568542
# MSFT     152.735065

# %%
bycomp.min()
# Out:
#           Person  Sales
# Company
# FB          Carl    243
# GOOGL    Charlie    120
# MSFT         Amy    124

# %%
bycomp.max()
# Out:
#           Person  Sales
# Company
# FB         Sarah    350
# GOOGL        Sam    200
# MSFT     Vanessa    340

# %%
bycomp.std()
# Out:
#               Sales
# Company
# FB        75.660426
# GOOGL     56.568542
# MSFT     152.735065

# %%
bycomp.sum().loc['FB']
# Out:
# Sales    593
# Name: FB, dtype: int64

# %%
df.groupby('Company').count() # common way to use grouby
# Out:
#          Person  Sales
# Company
# FB            2      2
# GOOGL         2      2
# MSFT          2      2

# %%
df.groupby('Company').describe() # describe returns a dataframe. descriptive statistics
# Out:
#         Sales
#         count   mean         std    min     25%    50%     75%    max
# Company
# FB        2.0  296.5   75.660426  243.0  269.75  296.5  323.25  350.0
# GOOGL     2.0  160.0   56.568542  120.0  140.00  160.0  180.00  200.0
# MSFT      2.0  232.0  152.735065  124.0  178.00  232.0  286.00  340.0

# %%
df.groupby('Company').describe().transpose() # switch rows and columns
# Out:
# Company              FB       GOOGL        MSFT
# Sales count    2.000000    2.000000    2.000000
#       mean   296.500000  160.000000  232.000000
#       std     75.660426   56.568542  152.735065
#       min    243.000000  120.000000  124.000000
#       25%    269.750000  140.000000  178.000000
#       50%    296.500000  160.000000  232.000000
#       75%    323.250000  180.000000  286.000000
#       max    350.000000  200.000000  340.000000

# %%
df.groupby('Company').describe().transpose()['FB'] # select whichever company you are interested in
# Out:
# Sales  count      2.000000
#        mean     296.500000
#        std       75.660426
#        min      243.000000
#        25%      269.750000
#        50%      296.500000
#        75%      323.250000
#        max      350.000000
# Name: FB, dtype: float64

# %%
# other ways to use group by
# credit_card_df.groupby('SEX_LABELLED').agg(MEAN=('LIMIT_BAL', np.mean),
#                                            QUARTILE_25th = ('LIMIT_BAL', lambda bal: bal.quantile(0.25)), 
#                                            MEDIAN = ('LIMIT_BAL', np.median),
#                                            QUARTILE_75th = ('LIMIT_BAL', lambda bal: bal.quantile(0.75)))

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %% [markdown]
# ![groupby.jpeg](attachment:groupby.jpeg)

# %% [markdown]
# ### QUICK REVIEW:
# 1. creating groupby object - `df.groupby('column_name')`
# 2. aggregation functions on groupby object - `mean(), sum(), min(), max(), count(), std()`
# 3. selecting particular group - `bycomp.sum().loc['FB']`
# 4. descriptive statistics - `describe()` `df.groupby('Company').describe()`
# 5. transpose - `transpose()`
#     `df.groupby('Company').describe().transpose()['FB']`
